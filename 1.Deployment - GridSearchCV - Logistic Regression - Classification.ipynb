# %%
#Syntax - Machine learning - GridSearchCV - Logistic Regression - Classification - Phase 2 - AI Model Deployment

# %%
import pickle #Pickle is a library

# %%
loaded_model=pickle.load(open("finalized_model_Logistic_Regression_Classification.sav",'rb'))
result=loaded_model.predict([[19,19000,1]])

# %%
result
# Out:
# array([1])
