# %%
#ML - Classification - Support Vector Machine - Algorithm - GridSearchCV Method - GridSearchCV is an automatic algorithm, parameter check, and creates a table, and
#Check & upload the confusion matrix Value automatically in the table.

# %%
#Importing the Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Reading the dataset
dataset=pd.read_csv("Social_Network_Ads.csv") #Dataset file name
dataset #Function call
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
#Categorical data converting into nominal data
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
indep=dataset[["Age","EstimatedSalary","Gender_Male"]] #Independent - Input dataset
dep=dataset["Purchased"] #Dependent - Output dataset

# %%
#split into training set and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
#StandardScaler for better results
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform (X_train)
X_test=sc.transform(X_test)

# %%
#Model Creation
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
param_grid= {'kernel':['rbf','poly','sigmoid','linear'],
              'C':[10,100,1000,2000,3000],'gamma':['auto','scale']}


grid=GridSearchCV(SVC(probability=True),param_grid, refit=True, verbose=3, cv=5, n_jobs=-1,scoring='f1_weighted')

#Fitting the model for grid search
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# GridSearchCV(cv=5, estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              scoring='f1_weighted', verbose=3)

# %%
#Print best parameter after tuning
#Print(grid.best_params_)
re=grid.cv_results_

#Print (re)
grid_predictions=grid.predict(X_test)

from sklearn.metrics import confusion_matrix #Confusion Matrix Identification
cm = confusion_matrix(y_test, grid_predictions)

from sklearn.metrics import classification_report #Classification Report
clf_report = classification_report(y_test, grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score (y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}: 0.9100355779243318

# %%
print("The Confusion Matrix:\n",cm)
# Out:
# The Confusion Matrix:
#  [[80  5]
#  [ 7 42]]

# %%
print("The Confusion Matrix:\n",clf_report)
# Out:
# The Confusion Matrix:
#                precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93        85
#            1       0.89      0.86      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.91      0.90      0.90       134
# weighted avg       0.91      0.91      0.91       134

# %%
from sklearn.metrics import roc_auc_score #ROC -Receiver Operating Characteristic, AUC - Area Under the Curve
roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.9539015606242497

# %%
#Table Creation
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.022327      0.007336         0.007822        0.001948       10
# 1        0.015646      0.000941         0.005543        0.000274       10
# 2        0.010853      0.000463         0.005379        0.000319       10
# 3        0.017389      0.000847         0.005221        0.000514       10
# 4        0.013163      0.000718         0.006220        0.000414       10
# 5        0.015580      0.001734         0.005557        0.000712       10
# 6        0.010417      0.000889         0.006010        0.000910       10
# 7        0.016666      0.001016         0.004888        0.000134       10
# 8        0.017130      0.001913         0.005182        0.000224      100
# 9        0.065979      0.007377         0.004766        0.000160      100
# 10       0.010683      0.001067         0.004645        0.000128      100
# 11       0.071833      0.034401         0.005367        0.001002      100
# 12       0.017499      0.001109         0.007854        0.003259      100
# 13       0.064795      0.021573         0.005282        0.000403      100
# 14       0.010435      0.001217         0.005273        0.000566      100
# 15       0.050035      0.004094         0.004976        0.000197      100
# 16       0.044537      0.006224         0.005275        0.000300     1000
# 17       0.454523      0.144941         0.004859        0.000302     1000
# 18       0.009746      0.000179         0.004735        0.000136     1000
# 19       0.297123      0.014917         0.004937        0.000253     1000
# 20       0.041451      0.004259         0.005314        0.000263     1000
# 21       0.543979      0.175134         0.005001        0.000198     1000
# 22       0.009979      0.000510         0.004905        0.000272     1000
# 23       0.322545      0.052944         0.005002        0.000538     1000
# 24       0.078467      0.012495         0.005619        0.000630     2000
# 25       0.998659      0.194777         0.005298        0.000535     2000
# 26       0.010372      0.000659         0.004623        0.000115     2000
# 27       0.695485      0.130211         0.004832        0.000179     2000
# 28       0.085498      0.010944         0.005271        0.000305     2000
# 29       0.998802      0.274951         0.004970        0.000333     2000
# 30       0.009984      0.000411         0.004596        0.000213     2000
# 31       0.759355      0.288517         0.004753        0.000223     2000
# 32       0.100130      0.015239         0.005827        0.001503     3000
# 33       1.505011      0.406854         0.004814        0.000291     3000
# 34       0.009845      0.000600         0.004716        0.000274     3000
# 35       1.003959      0.151946         0.005027        0.000369     3000
# 36       0.098493      0.026819         0.007731        0.004884     3000
# 37       1.653369      0.617729         0.004859        0.000173     3000
# 38       0.010034      0.000579         0.005058        0.000467     3000
# 39       0.807454      0.073235         0.004532        0.000503     3000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# 5        scale         poly
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto          rbf
# 9         auto         poly
# 10        auto      sigmoid
# 11        auto       linear
# 12       scale          rbf
# 13       scale         poly
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto          rbf
# 17        auto         poly
# 18        auto      sigmoid
# 19        auto       linear
# 20       scale          rbf
# 21       scale         poly
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto         poly
# 26        auto      sigmoid
# 27        auto       linear
# 28       scale          rbf
# 29       scale         poly
# 30       scale      sigmoid
# 31       scale       linear
# 32        auto          rbf
# 33        auto         poly
# 34        auto      sigmoid
# 35        auto       linear
# 36       scale          rbf
# 37       scale         poly
# 38       scale      sigmoid
# 39       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.867478
# 1        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0