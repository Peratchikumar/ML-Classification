# %%
#Syntax - Machine learning - Logistic Regression - Classification - Phase 2 - AI Model Deployment

# %%
import pickle #Pickle is a library

# %%
loaded_model=pickle.load(open("finalized_model_Social_Network_Ads.sav",'rb'))
result=loaded_model.predict([[27,57000,0]])
# Out:
# C:\Users\bkann\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([0])
